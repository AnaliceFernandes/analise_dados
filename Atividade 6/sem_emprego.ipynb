# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
path_2012 = r"H:\Python\3° ETAPA\Atividade 6\Tabela5-sem_emprego_2012.csv"
path_2026 = r"H:\Python\3° ETAPA\Atividade 6\Tabela5-sem_emprego_2026.csv"
path_horas = r"H:\Python\3° ETAPA\Atividade 6\Tabela 1.1.1.xls"

# %%
t2012 = pd.read_csv(path, sep = ";", encoding="utf8", decimal=",")

# %%
tab_2012 =t2012.rename(columns = {"Desocupados = homens (2012 T1)" : "homens_2012"})

# %%
tab_2012 =tab_2012.rename(columns = {"Desocupados - mulheres (2012 T1)" : "tab_2012"})

# %%
t2026 = pd.read_csv(path2,  sep = ";", encoding="utf8", decimal=",")

# %%
t2026 = t2026.rename(columns = {"Desocupados - homens (2026 T1)" : "homens_2026"})

# %%
ESTADO = "Minas Gerais"

# %%
t2012
# Out:
#    Sigla  Código               Estado  Desocupados - homens (2012 T1)  \
# 0     AC      12                 Acre                            45.3
# 1     AL      27              Alagoas                            44.7
# 2     AM      13             Amazonas                            47.5
# 3     AP      16                Amapá                            48.1
# 4     BA      29                Bahia                            43.8
# 5     CE      23                Ceará                            51.1
# 6     DF      53     Distrito Federal                            41.0
# 7     ES      32       Espírito Santo                            46.4
# 8     GO      52                Goiás                            41.0
# 9     MA      21             Maranhão                            47.2
# 10    MG      31         Minas Gerais                            43.1
# 11    MS      50   Mato Grosso do Sul                            47.2
# 12    MT      51          Mato Grosso                            44.1
# 13    PA      15                 Pará                            43.2
# 14    PB      25              Paraíba                            44.4
# 15    PE      26           Pernambuco                            43.9
# 16    PI      22                Piauí                            51.2
# 17    PR      41               Paraná                            40.3
# 18    RJ      33       Rio de Janeiro                            44.2
# 19    RN      24  Rio Grande do Norte                            51.0
# 20    RO      11             Rondônia                            43.4
# 21    RR      14              Roraima                            41.8
# 22    RS      43    Rio Grande do Sul                            42.8
# 23    SC      42       Santa Catarina                            42.7
# 24    SE      28              Sergipe                            46.5
# 25    SP      35            São Paulo                            45.4
# 26    TO      17            Tocantins                            55.3
#
#     Desocupados - mulheres (2012 T1)
# 0                               54.7
# 1                               55.3
# 2                               52.5
# 3                               51.9
# 4                               56.2
# 5                               48.9
# 6                               59.0
# 7                               53.6
# 8                               59.0
# 9                               52.8
# 10                              56.9
# 11                              52.8
# 12                              55.9
# 13                              56.8
# 14                              55.6
# 15                              56.1
# 16                              48.8
# 17                              59.7
# 18                              55.8
# 19                              49.0
# 20                              56.6
# 21                              58.2
# 22                              57.2
# 23                              57.3
# 24                              53.5
# 25                              54.6
# 26                              44.7

# %%
t2026
# Out:
#    Sigla  Código               Estado  homens_2026  \
# 0     AC      12                 Acre         53.2
# 1     AL      27              Alagoas         50.7
# 2     AM      13             Amazonas         46.8
# 3     AP      16                Amapá         51.1
# 4     BA      29                Bahia         44.7
# 5     CE      23                Ceará         52.7
# 6     DF      53     Distrito Federal         47.9
# 7     ES      32       Espírito Santo         47.5
# 8     GO      52                Goiás         47.5
# 9     MA      21             Maranhão         49.1
# 10    MG      31         Minas Gerais         48.6
# 11    MS      50   Mato Grosso do Sul         45.3
# 12    MT      51          Mato Grosso         42.8
# 13    PA      15                 Pará         48.3
# 14    PB      25              Paraíba         48.9
# 15    PE      26           Pernambuco         48.7
# 16    PI      22                Piauí         55.1
# 17    PR      41               Paraná         46.3
# 18    RJ      33       Rio de Janeiro         45.4
# 19    RN      24  Rio Grande do Norte         48.2
# 20    RO      11             Rondônia         33.0
# 21    RR      14              Roraima         43.4
# 22    RS      43    Rio Grande do Sul         47.4
# 23    SC      42       Santa Catarina         44.6
# 24    SE      28              Sergipe         40.3
# 25    SP      35            São Paulo         46.2
# 26    TO      17            Tocantins         46.2
#
#     Desocupados - mulheres (2026 T1)
# 0                               46.8
# 1                               49.3
# 2                               53.2
# 3                               48.9
# 4                               55.3
# 5                               47.3
# 6                               52.1
# 7                               52.5
# 8                               52.5
# 9                               50.9
# 10                              51.4
# 11                              54.7
# 12                              57.2
# 13                              51.7
# 14                              51.1
# 15                              51.3
# 16                              44.9
# 17                              53.7
# 18                              54.6
# 19                              51.8
# 20                              67.0
# 21                              56.6
# 22                              52.6
# 23                              55.4
# 24                              59.7
# 25                              53.8
# 26                              53.8

# %%
comp = t2012.merge(t2026, on=["Sigla", "Código", "Estado"], how="inner")

# %%
comp
# Out:
#    Sigla  Código               Estado  Desocupados - homens (2012 T1)  \
# 0     AC      12                 Acre                            45.3
# 1     AL      27              Alagoas                            44.7
# 2     AM      13             Amazonas                            47.5
# 3     AP      16                Amapá                            48.1
# 4     BA      29                Bahia                            43.8
# 5     CE      23                Ceará                            51.1
# 6     DF      53     Distrito Federal                            41.0
# 7     ES      32       Espírito Santo                            46.4
# 8     GO      52                Goiás                            41.0
# 9     MA      21             Maranhão                            47.2
# 10    MG      31         Minas Gerais                            43.1
# 11    MS      50   Mato Grosso do Sul                            47.2
# 12    MT      51          Mato Grosso                            44.1
# 13    PA      15                 Pará                            43.2
# 14    PB      25              Paraíba                            44.4
# 15    PE      26           Pernambuco                            43.9
# 16    PI      22                Piauí                            51.2
# 17    PR      41               Paraná                            40.3
# 18    RJ      33       Rio de Janeiro                            44.2
# 19    RN      24  Rio Grande do Norte                            51.0
# 20    RO      11             Rondônia                            43.4
# 21    RR      14              Roraima                            41.8
# 22    RS      43    Rio Grande do Sul                            42.8
# 23    SC      42       Santa Catarina                            42.7
# 24    SE      28              Sergipe                            46.5
# 25    SP      35            São Paulo                            45.4
# 26    TO      17            Tocantins                            55.3
#
#     Desocupados - mulheres (2012 T1)  homens_2026  \
# 0                               54.7         53.2
# 1                               55.3         50.7
# 2                               52.5         46.8
# 3                               51.9         51.1
# 4                               56.2         44.7
# 5                               48.9         52.7
# 6                               59.0         47.9
# 7                               53.6         47.5
# 8                               59.0         47.5
# 9                               52.8         49.1
# 10                              56.9         48.6
# 11                              52.8         45.3
# 12                              55.9         42.8
# 13                              56.8         48.3
# 14                              55.6         48.9
# 15                              56.1         48.7
# 16                              48.8         55.1
# 17                              59.7         46.3
# 18                              55.8         45.4
# 19                              49.0         48.2
# 20                              56.6         33.0
# 21                              58.2         43.4
# 22                              57.2         47.4
# 23                              57.3         44.6
# 24                              53.5         40.3
# 25                              54.6         46.2
# 26                              44.7         46.2
#
#     Desocupados - mulheres (2026 T1)
# 0                               46.8
# 1                               49.3
# 2                               53.2
# 3                               48.9
# 4                               55.3
# 5                               47.3
# 6                               52.1
# 7                               52.5
# 8                               52.5
# 9                               50.9
# 10                              51.4
# 11                              54.7
# 12                              57.2
# 13                              51.7
# 14                              51.1
# 15                              51.3
# 16                              44.9
# 17                              53.7
# 18                              54.6
# 19                              51.8
# 20                              67.0
# 21                              56.6
# 22                              52.6
# 23                              55.4
# 24                              59.7
# 25                              53.8
# 26                              53.8

# %%
indicador_1 = pd.read_excel(path_horas, engine="xlrd", header=None)

# %%
indicador_1= indicador_1.iloc[8:41].copy()
indicador_1.columns = [
    "uf_regiao",
    "total",
    "total_branca",
    "total_preta_parda",
    "homem_branca",
    "homem_preta_parda",
    "mulher_branca",
    "mulher_preta_parda",
]
indicador_1 = indicador_1.reset_index(drop=True)

# %%
indicador_1
# Out:
#               uf_regiao      total total_branca total_preta_parda  \
# 0                Brasil  16.985781     16.54593         17.333142
# 1                 Norte  16.187037    15.925246         16.256032
# 2              Rondônia  17.014162    16.727733         17.101523
# 3                  Acre  13.606903    13.806929         13.541399
# 4              Amazonas   16.80729    15.987545         16.995493
# 5               Roraima  13.639257    13.651755         13.633606
# 6                  Pará  16.474268    16.181627         16.560239
# 7                 Amapá  13.586656     14.38918         13.415091
# 8             Tocantins  15.815781    15.701788         15.768728
# 9              Nordeste  18.499396      18.1517         18.610911
# 10             Maranhão  16.669614    16.421773         16.708894
# 11                Piauí  17.960366    16.948094         18.231789
# 12                Ceará  19.499293     18.52712         19.882469
# 13  Rio Grande do Norte   18.30774    18.101853         18.445218
# 14              Paraíba  18.920816     18.88792         18.945306
# 15           Pernambuco  19.306249    18.950219         19.418444
# 16              Alagoas  20.217129    19.165111         20.560451
# 17              Sergipe  18.826541    17.264294         19.317934
# 18                Bahia  17.849776    17.538007         17.935566
# 19              Sudeste  17.104218    16.834863         17.397989
# 20         Minas Gerais  17.502141    17.179387         17.707564
# 21       Espírito Santo  17.111106     16.51061         17.478861
# 22       Rio de Janeiro  16.716263    16.097467          17.24306
# 23            São Paulo  17.071295    16.964437          17.25548
# 24                  Sul  15.527769    15.570983         15.406088
# 25               Paraná  15.390122    15.453295         15.307289
# 26       Santa Catarina  16.039355    16.124417         15.616235
# 27    Rio Grande do Sul  15.356709    15.337269         15.448203
# 28         Centro-Oeste  15.000763    14.826985         15.078025
# 29   Mato Grosso do Sul  15.309783    14.902105         15.567204
# 30          Mato Grosso  14.239989    14.083513         14.270209
# 31                Goiás  15.186471    14.962622         15.296966
# 32     Distrito Federal  15.096351    15.061306         15.126295
#
#    homem_branca homem_preta_parda mulher_branca mulher_preta_parda
# 0     11.705136          11.74633     20.404106          22.037998
# 1     11.588653         11.514646      19.29578          20.534188
# 2     12.111127          12.54408     20.412887           21.06141
# 3      10.79612          9.686983     16.130352          16.710754
# 4     12.233043         12.822584     18.764969          20.716986
# 5     10.814803         10.476601     16.135877          16.560244
# 6     11.524306         11.026707      19.83511          21.591144
# 7     11.116821         10.749444     16.648579          15.908487
# 8     10.733863         11.682616     19.663713          19.629399
# 9     11.723907         11.848436     22.744666          23.716716
# 10    11.665173         11.437359     19.881056          20.739589
# 11    12.258324         11.204814     20.494063           23.69544
# 12    12.186936         12.821323     23.019718          24.952274
# 13    11.166909         11.086286      23.54708          24.422884
# 14    12.480204         12.400831     23.642936           24.03565
# 15    12.312833         12.868821      23.35788          24.243396
# 16    12.121839          13.35716     24.093655          25.856637
# 17    10.830511         11.270341     21.740902          25.637681
# 18    10.551673         10.982808      22.57273          23.217119
# 19    11.933522         12.180843     20.732969          21.990431
# 20     11.31972          11.61912      22.18665          23.075751
# 21    11.798571         12.017589     20.464462          22.196626
# 22    12.000036         12.864896     19.203741          20.957728
# 23    12.123044           12.2352     20.771186           21.76762
# 24    11.546629         11.159487     19.012969          19.338734
# 25    11.240085         10.815611     18.896661           19.36538
# 26    12.339052         11.517342     19.414764          19.646573
# 27    11.308447         11.519941      18.86823           19.10772
# 28    10.546799         10.332059     18.220683           19.33104
# 29    10.446213          11.12692       18.5932          19.542761
# 30     9.479654          9.265734     17.782825          18.695923
# 31    10.636424         10.531883     18.440842          19.587913
# 32    11.377952         10.481279     17.738123          19.307332

# %%
regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]

estados = indicador_1[~indicador_1["uf_regiao"].isin(["Brasil"] + regioes)]

# %%
estados
# Out:
#               uf_regiao      total total_branca total_preta_parda  \
# 2              Rondônia  17.014162    16.727733         17.101523
# 3                  Acre  13.606903    13.806929         13.541399
# 4              Amazonas   16.80729    15.987545         16.995493
# 5               Roraima  13.639257    13.651755         13.633606
# 6                  Pará  16.474268    16.181627         16.560239
# 7                 Amapá  13.586656     14.38918         13.415091
# 8             Tocantins  15.815781    15.701788         15.768728
# 10             Maranhão  16.669614    16.421773         16.708894
# 11                Piauí  17.960366    16.948094         18.231789
# 12                Ceará  19.499293     18.52712         19.882469
# 13  Rio Grande do Norte   18.30774    18.101853         18.445218
# 14              Paraíba  18.920816     18.88792         18.945306
# 15           Pernambuco  19.306249    18.950219         19.418444
# 16              Alagoas  20.217129    19.165111         20.560451
# 17              Sergipe  18.826541    17.264294         19.317934
# 18                Bahia  17.849776    17.538007         17.935566
# 20         Minas Gerais  17.502141    17.179387         17.707564
# 21       Espírito Santo  17.111106     16.51061         17.478861
# 22       Rio de Janeiro  16.716263    16.097467          17.24306
# 23            São Paulo  17.071295    16.964437          17.25548
# 25               Paraná  15.390122    15.453295         15.307289
# 26       Santa Catarina  16.039355    16.124417         15.616235
# 27    Rio Grande do Sul  15.356709    15.337269         15.448203
# 29   Mato Grosso do Sul  15.309783    14.902105         15.567204
# 30          Mato Grosso  14.239989    14.083513         14.270209
# 31                Goiás  15.186471    14.962622         15.296966
# 32     Distrito Federal  15.096351    15.061306         15.126295
#
#    homem_branca homem_preta_parda mulher_branca mulher_preta_parda
# 2     12.111127          12.54408     20.412887           21.06141
# 3      10.79612          9.686983     16.130352          16.710754
# 4     12.233043         12.822584     18.764969          20.716986
# 5     10.814803         10.476601     16.135877          16.560244
# 6     11.524306         11.026707      19.83511          21.591144
# 7     11.116821         10.749444     16.648579          15.908487
# 8     10.733863         11.682616     19.663713          19.629399
# 10    11.665173         11.437359     19.881056          20.739589
# 11    12.258324         11.204814     20.494063           23.69544
# 12    12.186936         12.821323     23.019718          24.952274
# 13    11.166909         11.086286      23.54708          24.422884
# 14    12.480204         12.400831     23.642936           24.03565
# 15    12.312833         12.868821      23.35788          24.243396
# 16    12.121839          13.35716     24.093655          25.856637
# 17    10.830511         11.270341     21.740902          25.637681
# 18    10.551673         10.982808      22.57273          23.217119
# 20     11.31972          11.61912      22.18665          23.075751
# 21    11.798571         12.017589     20.464462          22.196626
# 22    12.000036         12.864896     19.203741          20.957728
# 23    12.123044           12.2352     20.771186           21.76762
# 25    11.240085         10.815611     18.896661           19.36538
# 26    12.339052         11.517342     19.414764          19.646573
# 27    11.308447         11.519941      18.86823           19.10772
# 29    10.446213          11.12692       18.5932          19.542761
# 30     9.479654          9.265734     17.782825          18.695923
# 31    10.636424         10.531883     18.440842          19.587913
# 32    11.377952         10.481279     17.738123          19.307332

# %%
estados = estados.rename(columns = {"uf_regiao" : "Estado"}).reset_index(drop=True)

# %%
comp = comp.merge(estados, on="Estado", how="inner")

# %%
comp
# Out:
#    Sigla  Código               Estado  Desocupados - homens (2012 T1)  \
# 0     AC      12                 Acre                            45.3
# 1     AL      27              Alagoas                            44.7
# 2     AM      13             Amazonas                            47.5
# 3     AP      16                Amapá                            48.1
# 4     BA      29                Bahia                            43.8
# 5     CE      23                Ceará                            51.1
# 6     DF      53     Distrito Federal                            41.0
# 7     ES      32       Espírito Santo                            46.4
# 8     GO      52                Goiás                            41.0
# 9     MA      21             Maranhão                            47.2
# 10    MG      31         Minas Gerais                            43.1
# 11    MS      50   Mato Grosso do Sul                            47.2
# 12    MT      51          Mato Grosso                            44.1
# 13    PA      15                 Pará                            43.2
# 14    PB      25              Paraíba                            44.4
# 15    PE      26           Pernambuco                            43.9
# 16    PI      22                Piauí                            51.2
# 17    PR      41               Paraná                            40.3
# 18    RJ      33       Rio de Janeiro                            44.2
# 19    RN      24  Rio Grande do Norte                            51.0
# 20    RO      11             Rondônia                            43.4
# 21    RR      14              Roraima                            41.8
# 22    RS      43    Rio Grande do Sul                            42.8
# 23    SC      42       Santa Catarina                            42.7
# 24    SE      28              Sergipe                            46.5
# 25    SP      35            São Paulo                            45.4
# 26    TO      17            Tocantins                            55.3
#
#     Desocupados - mulheres (2012 T1)  homens_2026  \
# 0                               54.7         53.2
# 1                               55.3         50.7
# 2                               52.5         46.8
# 3                               51.9         51.1
# 4                               56.2         44.7
# 5                               48.9         52.7
# 6                               59.0         47.9
# 7                               53.6         47.5
# 8                               59.0         47.5
# 9                               52.8         49.1
# 10                              56.9         48.6
# 11                              52.8         45.3
# 12                              55.9         42.8
# 13                              56.8         48.3
# 14                              55.6         48.9
# 15                              56.1         48.7
# 16                              48.8         55.1
# 17                              59.7         46.3
# 18                              55.8         45.4
# 19                              49.0         48.2
# 20                              56.6         33.0
# 21                              58.2         43.4
# 22                              57.2         47.4
# 23                              57.3         44.6
# 24                              53.5         40.3
# 25                              54.6         46.2
# 26                              44.7         46.2
#
#     Desocupados - mulheres (2026 T1)      total total_branca  \
# 0                               46.8  13.606903    13.806929
# 1                               49.3  20.217129    19.165111
# 2                               53.2   16.80729    15.987545
# 3                               48.9  13.586656     14.38918
# 4                               55.3  17.849776    17.538007
# 5                               47.3  19.499293     18.52712
# 6                               52.1  15.096351    15.061306
# 7                               52.5  17.111106     16.51061
# 8                               52.5  15.186471    14.962622
# 9                               50.9  16.669614    16.421773
# 10                              51.4  17.502141    17.179387
# 11                              54.7  15.309783    14.902105
# 12                              57.2  14.239989    14.083513
# 13                              51.7  16.474268    16.181627
# 14                              51.1  18.920816     18.88792
# 15                              51.3  19.306249    18.950219
# 16                              44.9  17.960366    16.948094
# 17                              53.7  15.390122    15.453295
# 18                              54.6  16.716263    16.097467
# 19                              51.8   18.30774    18.101853
# 20                              67.0  17.014162    16.727733
# 21                              56.6  13.639257    13.651755
# 22                              52.6  15.356709    15.337269
# 23                              55.4  16.039355    16.124417
# 24                              59.7  18.826541    17.264294
# 25                              53.8  17.071295    16.964437
# 26                              53.8  15.815781    15.701788
#
#    total_preta_parda homem_branca homem_preta_parda mulher_branca  \
# 0          13.541399     10.79612          9.686983     16.130352
# 1          20.560451    12.121839          13.35716     24.093655
# 2          16.995493    12.233043         12.822584     18.764969
# 3          13.415091    11.116821         10.749444     16.648579
# 4          17.935566    10.551673         10.982808      22.57273
# 5          19.882469    12.186936         12.821323     23.019718
# 6          15.126295    11.377952         10.481279     17.738123
# 7          17.478861    11.798571         12.017589     20.464462
# 8          15.296966    10.636424         10.531883     18.440842
# 9          16.708894    11.665173         11.437359     19.881056
# 10         17.707564     11.31972          11.61912      22.18665
# 11         15.567204    10.446213          11.12692       18.5932
# 12         14.270209     9.479654          9.265734     17.782825
# 13         16.560239    11.524306         11.026707      19.83511
# 14         18.945306    12.480204         12.400831     23.642936
# 15         19.418444    12.312833         12.868821      23.35788
# 16         18.231789    12.258324         11.204814     20.494063
# 17         15.307289    11.240085         10.815611     18.896661
# 18          17.24306    12.000036         12.864896     19.203741
# 19         18.445218    11.166909         11.086286      23.54708
# 20         17.101523    12.111127          12.54408     20.412887
# 21         13.633606    10.814803         10.476601     16.135877
# 22         15.448203    11.308447         11.519941      18.86823
# 23         15.616235    12.339052         11.517342     19.414764
# 24         19.317934    10.830511         11.270341     21.740902
# 25          17.25548    12.123044           12.2352     20.771186
# 26         15.768728    10.733863         11.682616     19.663713
#
#    mulher_preta_parda
# 0           16.710754
# 1           25.856637
# 2           20.716986
# 3           15.908487
# 4           23.217119
# 5           24.952274
# 6           19.307332
# 7           22.196626
# 8           19.587913
# 9           20.739589
# 10          23.075751
# 11          19.542761
# 12          18.695923
# 13          21.591144
# 14           24.03565
# 15          24.243396
# 16           23.69544
# 17           19.36538
# 18          20.957728
# 19          24.422884
# 20           21.06141
# 21          16.560244
# 22           19.10772
# 23          19.646573
# 24          25.637681
# 25           21.76762
# 26          19.629399

# %%
ordem = nomedatabela.insira aqui o comando para ordernar("coluna de ordenacao")["Estado"]
# Out:
#   Cell In[104], line 1
#     ordem = nomedatabela.insira aqui o comando para ordernar("coluna de ordenacao")["Estado"]
#                                 ^
# SyntaxError: invalid syntax

# %%
ordem
# Out:
# 20               Rondônia
# 24                Sergipe
# 12            Mato Grosso
# 21                Roraima
# 23         Santa Catarina
# 4                   Bahia
# 11     Mato Grosso do Sul
# 18         Rio de Janeiro
# 25              São Paulo
# 26              Tocantins
# 17                 Paraná
# 2                Amazonas
# 22      Rio Grande do Sul
# 7          Espírito Santo
# 8                   Goiás
# 6        Distrito Federal
# 19    Rio Grande do Norte
# 13                   Pará
# 10           Minas Gerais
# 15             Pernambuco
# 14                Paraíba
# 9                Maranhão
# 1                 Alagoas
# 3                   Amapá
# 5                   Ceará
# 0                    Acre
# 16                  Piauí
# Name: Estado, dtype: str

# %%
regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]

estados = indicador_1[~indicador_1["uf_regiao"].isin(["Brasil"] + regioes)]

# %%
longo = comp.melt(
    id_vars=["Sigla", "Código", "Estado"],
    value_vars=["mulheres_2012", "mulheres_2026"],
    var_name="Ano",
    value_name="Participacao_mulheres",
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 longo = comp.melt(
#       2     id_vars=["Sigla", "Código", "Estado"],
#       3     value_vars=["mulheres_2012", "mulheres_2026"],
#       4     var_name="Ano",
#       5     value_name="Participacao_mulheres",
#       6 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:11715, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#   11585 def melt(
#   11586     self,
#   11587     id_vars=None,
#    (...)
#   11592     ignore_index: bool = True,
#   11593 ) -> DataFrame:
#   11594     """
#   11595     Unpivot DataFrame from wide to long format, optionally leaving identifiers set.
#   11596
#    (...)
#   11713     2      c          B          E      5
#   11714     """
# > 11715     return melt(
#   11716         self,
#   11717         id_vars=id_vars,
#   11718         value_vars=value_vars,
#   11719         var_name=var_name,
#   11720         value_name=value_name,
#   11721         col_level=col_level,
#   11722         ignore_index=ignore_index,
#   11723     ).__finalize__(self, method="melt")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\melt.py:204, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     200 if missing.any():
#     201     missing_labels = [
#     202         lab for lab, not_found in zip(labels, missing, strict=True) if not_found
#     203     ]
# --> 204     raise KeyError(
#     205         "The following id_vars or value_vars are not present in "
#     206         f"the DataFrame: {missing_labels}"
#     207     )
#     208 if value_vars_was_not_none:
#     209     frame = frame.iloc[:, algos.unique(idx)]
#
# KeyError: "The following id_vars or value_vars are not present in the DataFrame: ['mulheres_2012', 'mulheres_2026']"

# %%
longo["Ano"] = longo["Ano"].map({"mulheres_2012": "2012 T1", "mulheres_2026": "2026 T1"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 longo["Ano"] = longo["Ano"].map({"mulheres_2012": "2012 T1", "mulheres_2026": "2026 T1"})
#
# NameError: name 'longo' is not defined

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(
    data=longo,
    y="Estado",
    x="Participacao_mulheres",
    hue="Ano",
    order=ordem,
    ax=ax,
)
ax.axvline(50, color="black", linestyle="--", linewidth=1)
ax.set_xlabel("Participação das mulheres entre as pessoas desocupadas (%)")
ax.set_ylabel("")
ax.set_title("Desocupação: participação feminina em 2012 T1 e 2026 T1")
ax.legend(title="Trimestre")
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 fig, ax = plt.subplots(figsize=(10, 10))
#       2 sns.barplot(
# ----> 3     data=longo,
#       4     y="Estado",
#       5     x="Participacao_mulheres",
#       6     hue="Ano",
#       7     order=ordem,
#       8     ax=ax,
#       9 )
#      10 ax.axvline(50, color="black", linestyle="--", linewidth=1)
#      11 ax.set_xlabel("Participação das mulheres entre as pessoas desocupadas (%)")
#
# NameError: name 'longo' is not defined

# %%
ordem = comp.sort_values("mulheres_2026", ascending=False)["Estado"]

longo = comp.melt(
    id_vars=["Sigla", "Código", "Estado"],
    value_vars=["mulheres_2012", "mulheres_2026"],
    var_name="Ano",
    value_name="Participacao_mulheres",
)
longo["Ano"] = longo["Ano"].map({"mulheres_2012": "2012 T1", "mulheres_2026": "2026 T1"})

fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(
    data=longo,
    y="Estado",
    x="Participacao_mulheres",
    hue="Ano",
    order=ordem,
    ax=ax,
)
ax.axvline(50, color="gray", linestyle="--", linewidth=1)
ax.set_xlabel("Participação das mulheres entre as pessoas desocupadas (%)")
ax.set_ylabel("")
ax.set_title("Desocupação: participação feminina em 2012 T1 e 2026 T1")
ax.legend(title="Trimestre")
fig.tight_layout()
fig.savefig("participacao_mulheres_desocupacao.png", dpi=150)
plt.show()

# %%
comp.to_csv("comp_tabela5_x_tabela1_1_1.csv", index=False)
